# %% [markdown]
# # Notebook 2: Exploratory Data Analysis
#
# ## RX-7281 Phase III Trial — Visual EDA
#
# This notebook performs comprehensive exploratory analysis of the clinical trial dataset:
# 1. **Demographics** — Age, sex, race, BMI distributions by treatment arm
# 2. **Biomarker Profiles** — Baseline inflammatory marker distributions
# 3. **Correlations** — Biomarker inter-relationships and outcome associations
# 4. **Missing Data** — Pattern analysis and impact assessment
# 5. **Outcome Preview** — Initial look at response rates and survival
